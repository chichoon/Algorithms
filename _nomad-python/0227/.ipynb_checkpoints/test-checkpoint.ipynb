# %%
import requests
from bs4 import BeautifulSoup
from indeed_func import get_jobs
#자주 쓸 코드를 함수화하여 불러옴

jobs = get_jobs()
# Out:
# 2021년 2월 Python 취업, 일자리, 채용
# ★Scrapping page 0 :
# ★Scrapping page 1 :
# ★Scrapping page 2 :
# ★Scrapping page 3 :
# ★Scrapping page 4 :
# [{'title': '2021 토스 전 계열사 대규모',
#   'company': '비바리퍼블리카',
#   'location': '서울 강남구',
#   'link': 'https://www.indeed.com/viewjob?jk=39e99c8ed1d40a8f'},
#  {'title': '2021년도 국가정보원 연계형 인턴 선발',
#   'company': '국가정보원',
#   'location': '서울 서초구',
#   'link': 'https://www.indeed.com/viewjob?jk=668a66da41da83d3'},
#  {'title': 'Machine Learning Researcher (Intern)',
#   'company': 'Qualcomm Korea YH',
#   'location': '서울',
#   'link': 'https://www.indeed.com/viewjob?jk=0f7993638aee82bd'},
#  {'title': '2021년 2월 경력사원 (Battery연구소)',
#   'company': 'LG에너지솔루션',
#   'location': '대전 유성구',
#   'link': 'https://www.indeed.com/viewjob?jk=31c20e6695f301ee'},
#  {'title': '데이터 분석가/사이언티스트(신입/인턴 가능)',
#   'company': '쏘카',
#   'location': '대한민국',
#   'link': 'https://www.indeed.com/viewjob?jk=55584c627df1acaa'},
#  {'title': '솔루션 엔지니어 (Network Infra)',
# ...
