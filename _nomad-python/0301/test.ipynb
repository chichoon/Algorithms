# %%
import requests
from bs4 import BeautifulSoup
from indeed_func import get_jobs as get_indeed_jobs
from sof_func import get_jobs as get_sof_jobs
#자주 쓸 코드를 함수화하여 불러옴

indeed_jobs = get_indeed_jobs()
sof_jobs = get_sof_jobs()
jobs = indeed_jobs + sof_jobs
# Out:
# IL', 'apply_link': 'https://stackoverflow.com/jobs/496603'}, {'title': 'HPC, Cloud or Storage System Engineer for Supercomputing', 'company': 'Forschungszentrum Jülich GmbH', 'location': 'Jülich, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/496602'}, {'title': 'Computer Vision Analyst, Research & Development', 'company': 'Houston Astros Baseball R&D', 'location': 'Houston, TX', 'apply_link': 'https://stackoverflow.com/jobs/295655'}, {'title': 'Site Reliability Engineer - Cyber Security', 'company': 'Myra Security GmbH', 'location': 'München, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/467130'}, {'title': 'Director of Engineering (Full Stack); Leader, Mentor, Partner - work with us!', 'company': 'Remixd Media', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/455957'}, {'title': 'Advanced Electrical Engineer (F/M/D)', 'company': 'NavVis GmbH', 'location': 'München, Germany', 'apply_link': 'https://stackoverflow.com/jobs/496591'}, {'title': 'Firmware Engineer', 'company': 'Adaptix Ltd', 'location': 'Kidlington, UK', 'apply_link': 'https://stackoverflow.com/jobs/496589'}, {'title': 'Software Engineer (Remote)', 'company': 'Knock.com', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/456289'}, {'title': 'Java Fullstack Entwickler (m/w/d) - Weinheim & remote', 'company': 'objective partner AG', 'location': 'Weinheim, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/496584'}, {'title': 'Senior Software Engineer', 'company': 'HealthJoy', 'location': 'Kyiv, Ukraine', 'apply_link': 'https://stackoverflow.com/jobs/457700'}, {'title': 'Core-team Full Stack Software Engineer (f/m/d)', 'company': 'ArcaScience', 'location': 'Paris, France', 'apply_link': 'https://stackoverflow.com/jobs/496582'}, {'title': 'Back-End Developer - Python', 'company': 'Imaginary Cloud', 'location': 'Lisbon, Portugal', 'apply_link': 'https://stackoverflow.com/jobs/496581'}, {'title': 'Junior Software Engineer im Firmenübergreifenden Trainee-Programm (100%)', 'company': 'M&F Engineering AG', 'location': 'Weiningen, Schweiz', 'apply_link': 'https://stackoverflow.com/jobs/233263'}, {'title': 'C++ Engineer - Desktop', 'company': 'Spotify', 'location': 'Stockholm, Sweden', 'apply_link': 'https://stackoverflow.com/jobs/496575'}, {'title': 'Static Code Analysis - Senior Java Developer', 'company': 'SonarSource', 'location': 'Geneva, Switzerland', 'apply_link': 'https://stackoverflow.com/jobs/466843'}, {'title': 'Cloud / GitOps Engineer', 'company': 'Metaswitch Networks', 'location': 'London Borough of Enfield, UK', 'apply_link': 'https://stackoverflow.com/jobs/456264'}, {'title': 'Software Engineering Manager (Python / GCP) (Global Service Tech) (f/m/d)', 'company': 'Delivery Hero SE', 'location': 'Berlin, Germany', 'apply_link': 'https://stackoverflow.com/jobs/454976'}, {'title': 'Softwareentwickler(m/w/d) Lokalisierung & Digitale Karten SLAM Autonomes Fahren', 'company': 'Elektronische Fahrwerksysteme GmbH', 'location': 'Gaimersheim, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/381691'}, {'title': 'Softwareentwickler (m/w/d) Referenzsensorik für automatisierte Fahrfunktionen', 'company': 'Elektronische Fahrwerksysteme GmbH', 'location': 'Gaimersheim, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/381693'}, {'title': 'Softwareentwickler (m/w/d) im Cloud Bereich', 'company': 'Elektronische Fahrwerksysteme GmbH', 'location': 'Gaimersheim, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/381695'}, {'title': 'Senior Frontend Engineer (JS TS React)', 'company': 'Zoopla', 'location': 'London, UK', 'apply_link': 'https://stackoverflow.com/jobs/496547'}, {'title': 'SOFTWARE CRAFT(WO)MAN Java et/ou JS', 'company': 'Arolla', 'location': 'Paris, France', 'apply_link': 'https://stackoverflow.com/jobs/496545'}, {'title': 'Training & Documentation Manager', 'company': 'Sepasoft, Inc.', 'location': 'El Dorado Hills, CA', 'apply_link': 'https:/ ...
