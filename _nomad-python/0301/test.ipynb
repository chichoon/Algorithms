# %%
import requests
from bs4 import BeautifulSoup
from indeed_func import get_jobs as get_indeed_jobs
from sof_func import get_jobs as get_sof_jobs
#자주 쓸 코드를 함수화하여 불러옴

#indeed_jobs = get_indeed_jobs()
#print(indeed_jobs)
sof_jobs = get_sof_jobs()
# Out:
# ud Architect
# uShip Austin, TX
# Software Engineer – Focused Geospatial Products
# Esri Redlands, CA
# Product Engineer – Focused Geospatial Products
# Esri Redlands, CA
# Senior Python Backend Engineer
# Kranus Health GmbH München, Deutschland
# Network Senior Engineer
# Telstra Bengaluru, India
# Software Engineer (ML)
# Parenthetic Arlington, VA
# Senior Data Scientist (NLP)
# Parenthetic Arlington, VA
# Junior Data Scientist (UK or Italy)
# InReach Ventures London, UK
# Technical Solutions Engineer (Python)
# Zyte (formerly Scrapinghub) No office location
# Senior Data Engineer
# Citizens Bank Providence, RI
# Senior Backend Python Developer (Copenhagen)
# GameAnalytics Copenhagen, Denmark
# Frontend Developer
# Frequenz Energy-as-a-Service GmbH Berlin, Germany
# Software Supply Chain Engineer
# SUSE No office location
# Python Backend Developer / Data Engineer (m/f/d) for Geo Applications (Munich)
# GAF AG München, Deutschland
# Software Engineer/SRE with Java or Python
# JPMorgan Chase Bank, N.A. Wilmington, DE
# Software Engineer (f/m/d) Machine Learning
# Leica Geosystems AG Heerbrugg, Schweiz
# Software C++ Engineer Metrology EUV
# ASML Veldhoven, Netherlands
# Fullstack Developer (m/f/d) Product HR Assistant
# Haufe Group Freiburg im Breisgau, Deutschland
# DevOps Engineer (m/w/d)
# Mimacom Stuttgart, Deutschland
# Senior DevOps Engineer
# Arachnys No office location
# DevOps Engineer
# Actio Berlin, Germany
# TechOps Engineer
# Virtasant Inc No office location
# Team Lead Engineering (Infrastructure)
# MessageBird No office location
# Senior Frontend-Entwickler*in
# Convit GmbH Köln, Deutschland
# Backend Software Engineer, TikTok
# ByteDance Singapore
# Data Engineer - Python
# Sytac IT Consulting Amsterdam, Netherlands
# Lead Vue.js / PHP developer
# HUBX No office location
# QA Engineer (m/f/x)
# ottonova München, Germany
# DevOps Engineer (m/w/d)
# tarent solutions GmbH Bonn, Deutschland
# Data Scientist
# Beatrust Inc. Minato City, Japan
# IoT Solutions Developer (m/w/d)
# MVI SOLVE-IT GmbH München, Deutschland
# Manager of Software Engineering
# Packet Fabric No office location
# Software Engineer
# Audatic GmbH Berlin, Germany
# Senior Deep Learning Engineer
# Audatic GmbH Berlin, Germany
# Equity Derivatives Technology - C#/ Java Developer, Assoc/VP
# JPMorgan Chase Bank, N.A. Hong Kong
# Full Stack Java Script / Java Software Engineer
# JPMorgan Chase Bank, N.A. Jersey City, NJ
# Sr/Staff/Principal Software Engineer - Cloud and Big Data
# JPMorgan Chase Bank, N.A. Seattle, WA
# Big Data / Java Software Engineer
# JPMorgan Chase Bank, N.A. New York, NY
# Software Engineering and Infrastructure Engineering Opportunities
# JPMorgan Chase Bank, N.A. Tampa, FL
# Product Analyst Sr. - Pricing and Analytics - Consumer
# JPMorgan Chase Bank, N.A. Columbus, OH
# Data Scientist
# Trilliant Health Nashville, TN
# SRE - Supportability Engineer
# JPMorgan Chase Bank, N.A. Buenos Aires, Argentina
# Software Engineering - BigData with Spark & Java
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Senior Java Software Engineer with C# experience
# JPMorgan Chase Bank, N.A. Chicago, IL
# Site Reliability Engineer - Public Cloud
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Application Modernization - Technology Governance
# JPMorgan Chase Bank, N.A. Wilmington, DE
# Java Cloud Full Stack Software Engineering Lead
# JPMorgan Chase Bank, N.A. Columbus, OH
# Infrastructure Engineering
# JPMorgan Chase Bank, N.A. Plano, TX
# Infrastructure Engineering
# JPMorgan Chase Bank, N.A. Tampa, FL
# Big Data Team Lead
# JPMorgan Chase Bank, N.A. Herzliya, Israel
# Applied Machine Learning Engineer
# JPMorgan Chase Bank, N.A. Seattle, WA
# Applications Support
# JPMorgan Chase Bank, N.A. Mumbai, India
# Software Engineering - Site Reliability Engineer / Kubernetes DevOps
# JPMorgan Chase Bank, N.A. Orem, UT
# J2ee-Software Engineering
# JPMorgan Chase Bank, N.A. Hyderabad, India
# JavaScript/ React Software Engineer-Glasgow
# JPMorgan Chase Bank, N.A. Glasgow, UK
# Red Team Operator
# JPMorgan Chase Bank, N.A. Wilmington, DE
# Merchant Services - Helix, Production Management, Site Reliability Engineer, Associate
# JPMorgan Chase Bank, N.A. Singapore
# Associate, Software Engineering
# JPMorgan Chase Bank, N.A. Houston, TX
# Infrastructure Developer (Data Protection)
# JPMorgan Chase Bank, N.A. Houston, TX
# Software Engineering
# JPMorgan Chase Bank, N.A. Newark, DE
# Applications Support SRE Lead
# JPMorgan Chase Bank, N.A. Tampa, FL
# Software Engineering Manager - Voice Recording & Recognition
# JPMorgan Chase Bank, N.A. Columbus, OH
# Java Developer
# JPMorgan Chase Bank, N.A. Plano, TX
# Software Engineering
# JPMorgan Chase Bank, N.A. Hyderabad, India
# Senior Data Engineer
# Unlearn.ai San Francisco, CA
# Senior Software Engineer
# JPMorgan Chase Bank, N.A. Houston, TX
# Python Software Engineer
# JPMorgan Chase Bank, N.A. Glasgow, UK
# Software Engineering
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Applications Support
# JPMorgan Chase Bank, N.A. New York, NY
# Senior Software Engineer (Full Stack)
# ShareStream No office location
# Senior Software Development Engineer
# Amazon Web Services Berlin, Germany
# Software Developer, Information Systems
# Defence Science and Technology Agency (DSTA) Singapore
# Cybersecurity Software Developer
# Defence Science and Technology Agency (DSTA) Singapore
# Full Stack Software Engineer
# kaliber.ai San Francisco, CA
# DevOps Engineer
# Techcyte, Inc. Orem, UT
# DevOps Engineer - ArcGIS Online Hosted Services
# Esri Redlands, CA
# Ruby on Rails Developer
# Imaginary Cloud Lisbon, Portugal
# Software Engineer, Back End
# Niche.com Pittsburgh, PA
# 154497BR - Sr Technical Analyst - Operations/Applications Support
# T-MobileviaPeopleScout Atlanta, GA
# Senior DevOps Engineer
# Unlearn.ai San Francisco, CA
# (Senior) Backend Engineer at sustainable mobility Start-up (m/f/x)
# finn.auto München, Deutschland
# Software Development Engineer
# OpenMarket Guadalajara, Mexico
# Software Engineer - Java SRE
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Senior Full Stack Java Developer
# JPMorgan Chase Bank, N.A. Durham, NC
# Senior Cloud Platform Business Intelligence Platform Engineer
# JPMorgan Chase Bank, N.A. Columbus, OH
# Senior Site Reliability Software Engineer
# JPMorgan Chase Bank, N.A. Houston, TX
# DevOps Automation Engineer
# JPMorgan Chase Bank, N.A. Plano, TX
# Senior ML Engineer
# JPMorgan Chase Bank, N.A. Herzliya, Israel
# Software Engineer - Public Cloud
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Software Engineer - Corporate Technology | CCB Risk - QMT Americas
# JPMorgan Chase Bank, N.A. Lewisville, TX
# Full Stack Software Engineer
# JPMorgan Chase Bank, N.A. Glasgow, UK
# Site Reliability Engineer Lead
# JPMorgan Chase Bank, N.A. Columbus, OH
# Software Engineering - Microservices Frameworks (Polyglot Programmers)
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Private Cloud Core Software Engineer
# JPMorgan Chase Bank, N.A. Bournemouth, UK
# Futures & Options Technical BA/ PM, Vice President
# JPMorgan Chase Bank, N.A. Singapore
# Technology Operations - Associate
# JPMorgan Chase Bank, N.A. Hyderabad, India
# Application Support - Unix/Python
# JPMorgan Chase Bank, N.A. Buenos Aires, Argentina
# Infrastructure Developer
# JPMorgan Chase Bank, N.A. Houston, TX
# Applications Support
# JPMorgan Chase Bank, N.A. Bengaluru, India
# CIB Technology - Business Analysis - Associate
# JPMorgan Chase Bank, N.A. Shanghai, China
# Senior Python Engineer - Commodities Technology - London
# JPMorgan Chase Bank, N.A. London, UK
# Software Engineering - Java
# JPMorgan Chase Bank, N.A. Glasgow, UK
# QA Functional Automation Tester
# JPMorgan Chase Bank, N.A. Hyderabad, India
# UI Software Engineer
# JPMorgan Chase Bank, N.A. Jersey City, NJ
# Senior Software Engineer (Full Stack)
# JPMorgan Chase Bank, N.A. Glasgow, UK
# Data Engineer
# JPMorgan Chase Bank, N.A. New York, NY
# Business Analyst I
# JPMorgan Chase Bank, N.A. Mumbai, India
# Software Engineering - Core Java - Mumbai
# JPMorgan Chase Bank, N.A. Mumbai, India
# Software Engineer
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Capital Tech BLR - Associate Developer
# JPMorgan Chase Bank, N.A. Bengaluru, India
# Python Software Engineer - Commodities - Front Office Athena, Associate
# JPMorgan Chase Bank, N.A. Singapore
# Senior Front End Engineer, Pet Health-R8355
# Chewy, Inc. Boston, MA
# Senior Cloud Security Engineer-R9098
# Chewy, Inc. Dania Beach, FL
# Platform Engineer
# GreenKey No office location
# Sr. Python Software Engineer
# Global Reach Consulting LLC Reston, VA
# Software Engineer
# Intruder London, UK
# Senior Software Engineer
# Intruder London, UK
# Software Architect
# Amida Technology Solutions Washington, DC
# Software Developer (Remote Available)
# Clio Calgary, AB, Canada
# Software Development Manager, Site Reliability Engineer
# Clio Toronto, ON, Canada
# Senior Automation Engineer
# Wunderkind New York, NY
# Sr. Software Developer - Backend Platform
# SWIMLANE INC No office location
# Software Engineer (Salesforce)
# Packet Fabric No office location
# DevOps Software Engineer (Data Engineering Team) - DU Grade
# Lloyds Banking Group London, UK
# Senior Software Engineer: Sell-Side Trading Platform
# Bloomberg LP New York, NY
# Front End Software Engineer
# Global Reach Consulting LLC Reston, VA
# Data & Machine Learning Engineer
# GeoPhy Den Haag, Netherlands
# Graduate Software Developer - 2021
# FINBOURNE Technology London, UK
# Praktikant (m/w/d) Data Analytics
# ING Deutschland Frankfurt am Main, Deutschland
# Big Data & Cloud QA Automation Engineer Platform Team
# Mimecast London, UK
# Principal Staff Engineer
# Skyscanner Shenzhen, China
# Principal Mobile Software Engineer
# Skyscanner London, UK
# Linux Administrator AWS (m/w/d)
# root360 GmbH Leipzig, Deutschland
# Python Developer/ Data Engineer
# Huxley Banking & Financial ServicesviaHuxley (US) New York, NY
# Senior Fullstack Python Developer
# Backtracks Austin, TX
# Senior DevOps Engineer (x/f/m)
# Wonder Berlin, Germany
# Wissenschaftliche*r Mitarbeiter*in Datenökosystem / Digitalisierungsmethoden
# Fraunhofer-Institut für Werkstoffmechanik IWM Freiburg im Breisgau, Deutschland
# Python Developer/ Trading Systems Engineer
# Huxley Banking & Financial ServicesviaHuxley (US) New York, NY
# Senior Platform Infrastructure Engineer
# Olo No office location
# C++ developer in Berlin. 120 000 euro per year
# think-cell Berlin, Germany
# Systemadministrator*in / System Engineer* – Linux / Network Operation Center
# Fraunhofer-Institut für Optronik, Systemtechnik und Bildauswertung IOSB Karlsruhe, Deutschland
# Data Engineer
# Montash Amsterdam, Netherlands
# Infrastructure Engineer
# Omnivore Technologies Clearwater, FL
# Finance Engineering Tech Lead (Remote-LATAM)
# Loadsmart No office location
# DevOps Engineer
# Red Bull Media House GmbH Elsbethen, Österreich
# Software Engineer (DWH/ BigData) @Poland
# PAYBACK Warszawa, Polen
# Senior QA Automation Engineer
# aklamio Berlin, Germany
# Senior Backend Developer (Python/Apache Kafka)
# dresslife Hanover, Germany
# Senior Software Developer C++
# By - Access Control Systems Madrid, Spain
# Software Developer Trainer
# Mayden Bath, UK
# Sr. DevOps Engineer
# Global Reach Consulting LLC Reston, VA
# AWS Infrastructure Engineer
# Tutuka No office location
# Full Stack Software Engineer
# Global Reach Consulting LLC Reston, VA
# Senior Distributed Systems Engineer (Java)
# Skyscanner Ltd. Edinburgh, UK
# DevOps Engineer (m/w/d)
# Geutebrück GmbH Bonn, Deutschland
# Platform Engineer (DevOps, AWS, Azure, Java, Python)
# buildit Warsaw, Poland
# Technical Lead
# ENGIE Digital Paris, France
# Tech Lead Agathe
# ENGIE Digital Paris, France
# SRE(Site Reliability Engineer)
# ENGIE Digital Paris, France
# Senior Full Stack Engineer
# Audacia Group No office location
# Software developer for test automation (f/m/x)
# OMICRON electronics GmbH Klaus, Austria
# Senior DevOps Engineer
# Wallbox Chargers SL Barcelona, Spain
# AutomationTest Lead
# Nominet Oxford, UK
# QA Automation Engineer
# Nominet Oxford, UK
# Principal Member of Technical Staff (Cloud Engineering Infrastructure Development) (JoinOCI-REI)
# Oracle Vilnius, Lithuania
# Technology Expert / Software Developer (w/m/d) Machine Learning
# Siemens Healthcare GmbH Forchheim, Deutschland
# Chromium Software Engineer
# eyeo GmbH No office location
# Software Reverse Engineer (m/w/d)
# Bundesnachrichtendienst Berlin, Deutschland
# CNE-Entwickler/innen (m/w/d)
# Bundesnachrichtendienst Berlin, Deutschland
# Senior C++ Developer
# FileWave Gmbh Düsseldorf, Germany
# Hacker – CNE-Operator (m/w/d)
# Bundesnachrichtendienst Berlin, Deutschland
# Hacker – CNE-Operator (m/w/d)
# Bundesnachrichtendienst Berlin, Deutschland
# Senior Django Developer
# FileWave Gmbh Düsseldorf, Germany
# Senior Java developer
# Riscure BV Delft, Netherlands
# Full Stack Software Engineer
# Displayr Glebe, Australia
# Principal Software Developer IC4 (JoinOCI-SDE)
# Oracle Bengaluru, India
# DevOps Architect
# Oracle Bengaluru, India
# Software Engineer - SRE|DevOps (Join OCI)
# Oracle Guadalajara, Mexico
# Sr. Software Engineer (Join OCI)
# Oracle Guadalajara, Mexico
# Site Reliability Engineer (SRE) (JoinOCI-SDE)
# Oracle Bucharest, Romania
# Site Reliability Engineer, Data & AI Services (NSC)
# Oracle Reading, UK
# Software Engineer (Test Software)
# SpaceX Hawthorne, CA
# Senior Full Stack Software Engineer
# Family Zone Perth, Australia
# Backend Engineer
# Hiretual Mountain View, CA
# Python Backend Lead Engineer
# Geomagical Labs Mountain View, CA
# Cloud DevOps Engineer
# Tenet3 Dayton, OH
# Site Reliability Engineer, APAC
# Canonical No office location
# Web Developer (maps and routes)
# Tortoise Inc Ciudad de México, Mexico
# Experienced Cloud Platform Engineer
# Varen Technologies Columbia, MD
# Geospatial Developer
# Geographic Information Services, Inc. Birmingham, AL
# Unreal Software Developer
# Scanline VFX No office location
# Senior Full Stack Software Engineer
# The Washington Post No office location
# Blockchain Engineer: Trading Applications
# Hummingbot No office location
# Backend Software Engineer (US-based)
# Hummingbot No office location
# Senior Software Developer
# Bankhead Technologies, Inc. Las Vegas, NV
# Software Engineer, Integration QA, Python
# Canonical No office location
# Site Reliability Engineer, Americas (Remote)
# Canonical No office location
# Cloud Operations Engineer, Americas (Remote)
# Canonical No office location
# Software Architect
# Trafilea No office location
# Software Engineer - Cloud Images
# Canonical No office location
# Linux Kernel Engineer
# Canonical Taipei, Taiwan
# Data Scientist
# Frequenz Energy-as-a-Service GmbH Berlin, Germany
# Sr. Data Engineer
# Empiric Health No office location
# Senior Backend Engineer (Python)
# HealthJoy No office location
# Data Engineer
# Real StaffingviaReal Staffing US South San Francisco, CA
# Senior Full-stack Web Developer
# Rocket Referrals Des Moines, IA
# Senior backend / embedded systems engineer (REMOTE in NC)
# NDSL Inc Raleigh, NC
# Data Infra: Developer
# Huxley Banking & Financial ServicesviaHuxley (US) Chicago, IL
# Cloud Ops Engineer (AWS)
# B-Line Medical Washington, DC
# Senior Autonomy Engineer - State Estimation
# Shield AI San Diego, CA
# Principal Data Engineer
# Huxley Banking & Financial ServicesviaHuxley (US) New York, NY
# Senior Python Engineer
# YouGov No office location
# Senior Front End Engineer
# Bushel Fargo, ND
# Senior DevOps Engineer
# Bushel Fargo, ND
# Supply Chain Systems Support Lead
# Apple Austin, TX
# Fullstack Engineer for Product Engineering
# Trustpilot Vilnius, Lithuania
# Data Scientist (m/w/d)
# emax digital GmbH Munich, Germany
# Cloud SWE Engineer
# Clarity Innovations LLC Annapolis Junction, MD
# Front-End Developer
# Imaginary Cloud Lisbon, Portugal
# Senior DevOps Engineer - London
# The Orchard London, UK
# Backend Software Engineer, Creator Tooling
# Actio Berlin, Germany
# Cloud Engineer
# Ocado Technology Wrocław, Poland
# Senior Python Developer (m//f/d) with Kubernetes-Focus for Monitoring-Company
# tribe29 GmbH München, Deutschland
# Full Stack Developer
# OpsTalent Wrocław, Poland
# Data Scientist (m/f/d)
# creditshelf Frankfurt am Main, Deutschland
# AI/ML - Software Engineer, Siri Engineering Efficiency
# Apple Yokohama, Japan
# Apple Pay - Software Development Engineer (Quality)
# Apple London, UK
# Systems Software Engineer - OS/Virtualization
# Apple Cupertino, CA
# Senior Site Reliability Engineer
# Mollie Amsterdam, Netherlands
# Ruby / Elixir Developer
# Scripbox Bengaluru, India
# Cloud Engineer for George (all genders)
# Erste Group Wien, Austria
# Backend Engineer (Zurich)
# Yova AG Zürich, Switzerland
# Fullstack Developer (f/m/d)
# TeleClinic GmbH München, Deutschland
# Administrateur Système F/H
# Akeneo Nantes, France
# Senior Data Engineer (f/m/d)
# Mimi Hearing Technologies GmbH Berlin, Germany
# Lead Python / Django Developer (f/m/d)
# TeleClinic GmbH München, Deutschland
# Back-End Engineer (.NET) (f/m/d) - Remote
# HeidelbergCement AG No office location
# Senior Full Stack Engineer interested in collaborative hardware development
# Wikifactory No office location
# Senior Backend Engineer, VMC on AWS
# VMware Bulgaria Sofia, Bulgaria
# Fully Cleared Java Software Developer Opportunity
# Varen Technologies Columbia, MD
# Django Engineer (m/f) for Germany's leading local marketing platform
# RegioHelden GmbH Stuttgart, Deutschland
# Senior Backend Engineer - VMware Carbon Black
# VMware Bulgaria Sofia, Bulgaria
# AI / Data Science Trainer (Antwerpen)
# BeCode VZW Antwerpen, Belgium
# ETL Developer
# Vattenfall Amsterdam, Netherlands
# Senior DevSecOps Software Engineer
# Worldline Stockholm, Sweden
# DevSecOps Software Engineer
# Worldline Stockholm, Sweden
# DevSecOps Software Architect
# Worldline Stockholm, Sweden
# Data Engineer
# KidsLoop Seoul, South Korea
# Senior Backend Developer
# KidsLoop Seoul, South Korea
# Backend Engineer (C++, Golang, Nodejs)
# SHIELD Singapore
# Backend Developer
# KidsLoop Seoul, South Korea
# Self-Starter Rapid-Prototyping DoD Network Software Developers
# Varen Technologies Columbia, MD
# Senior Engineer- Algorithms
# Econolite Colorado Springs, CO
# Project Manager Business Analyst
# GridUnity, Inc No office location
# Software Engineer - Ubuntu Server
# Canonical No office location
# Analytics Software Engineer
# NowPow Chicago, IL
# Software Engineer
# DialogTech No office location
# Sr. Manager of Core Product Engineering
# Mattermost, Inc No office location
# Cloud Security Engineer
# Mattermost, Inc No office location
# Software Development Engineer in Test (SDET)
# WELL Health Inc. Santa Barbara, CA
# Software Developer
# AbCellera Vancouver, BC, Canada
# Senior/Staff Data Engineer
# Evidation Health Santa Barbara, CA
# Senior/Staff DevOps Engineer
# Evidation Health Santa Barbara, CA
# Lead REACT (/iOS or Android) Frontend Software Engineer
# Givelify No office location
# System Engineer - Corporate IT (m|w|x)
# idealo internet GmbH Berlin, Deutschland
# Full-stack Javascript Developer (React.js/Node.js)
# Imaginary Cloud Lisbon, Portugal
# Python Software Engineer Intern for Geospatial AI Platform Team
# Blackshark.ai GmbH Graz, Österreich
# Senior Software Engineer (Security) - 100% remote (UK/EU only)
# Form3 - Financial Cloud London, UK
# Senior Full Stack Engineer
# GridUnity, Inc Boston, MA
# Cockpit (PVI) Software Developer
# Hellebore Consulting Group, LLC Wright-Patterson Air Force Base, OH
# Embedded Software Developer (IoT)
# ESKI Inc. (PixMob | klik | Safeteams) Montreal, QC, Canada
# Senior Full-Stack Application Engineer
# Hellebore Consulting Group, LLC Wright-Patterson Air Force Base, OH
# Full Stack Software Developer (remote - EU)
# Optimile Ghent, Belgium
# Embedded Linux Test Engineer (m/w/d)
# emlix GmbH Göttingen, Deutschland
# Senior Superhero Python Developer to protect the Bank from counterparty risk
# Deutsche BankviaJWiderberg Inc. DBA Insight Resource Group New York, NY
# Python Service Developer (m/w/d)
# Enote GmbH Berlin, Deutschland
# Lead Security Engineer (Remote-LATAM)
# Loadsmart No office location
# Software Entwickler (Python/C++)
# JC Development AG Glarus, Switzerland
# Embedded Linux System Engineer (m/w/d)
# emlix GmbH Berlin, Deutschland
# Data Engineer
# Everli No office location
# Software QA Tester
# Springbit, Inc. Alpharetta, GA
# DevOps Engineer
# YouGov Warsaw, Poland
# Softwareentwickler/in (m/w/d)
# vyble AG (vyble.io) Rostock, Deutschland
# Director of Software Engineering - Non Commission Revenue (f/m/d)
# Delivery Hero SE Berlin, Germany
# Back End Developer
# Yogaia Espoo, Finland
# Senior Software Developer (Java)
# Clickatell Pty Ltd Toronto, ON, Canada
# Fullstack Entwickler (m/w/d) für R-/Python-Applikationen
# Bundesdruckerei GmbH Hannover, Deutschland
# Software Engineer - Data Science QA Infrastructure
# Snke OS GmbH Munich, Germany
# Product Owner & Project Manager (m/f/d) - Web/ App
# Motius GmbH Stuttgart, Deutschland
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b3e761a7b483> in <module>
#       7 #indeed_jobs = get_indeed_jobs()
#       8 #print(indeed_jobs)
# ----> 9 sof_jobs = get_sof_jobs()
#
# c:\Users\jiyoo\Documents\GitHub\python_alg\_nomad-python\0301\sof_func.py in get_jobs()
#      43     jobs = []
#      44     max_pages = extract_pages()
# ---> 45     jobs = save_jobs(max_pages)
#      46     return jobs
#
# c:\Users\jiyoo\Documents\GitHub\python_alg\_nomad-python\0301\sof_func.py in save_jobs(last_page)
#      30     jobs = []
#      31     for page in range(last_page):
# ---> 32         result = requests.get(f"{URL}&pg={page + 1}")
#      33         soup = BeautifulSoup(result.text, "html.parser")
#      34         results = soup.find_all("div", {"class":"-job"})
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:
